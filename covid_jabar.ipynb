# %% [markdown]
# <a href="https://colab.research.google.com/github/setyo-dwi-pratama/covid-19/blob/master/covid_jabar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests
import urllib3
from urllib3 import request
import certifi

# %%
from pandas.io.json import json_normalize

# %%
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
url = 'https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json'

# %%
r = http.request('GET', url)

# %%
r.status
# Out:
# 200

# %%
data = json.loads(r.data.decode('utf-8'))

# %%
data
# Out:
# {'data': {'kasus': {'gejala': {'current_data': 220,
#     'list_data': [{'doc_count': 72.72727272727273, 'key': 'BATUK'},
#      {'doc_count': 43.18181818181818, 'key': 'SESAK NAPAS'},
#      {'doc_count': 42.72727272727273, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 33.63636363636363, 'key': 'PILEK'},
#      {'doc_count': 33.18181818181819, 'key': 'DEMAM'},
#      {'doc_count': 32.72727272727273, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 30.0, 'key': 'LEMAS'},
#      {'doc_count': 18.181818181818183, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 16.818181818181817, 'key': 'KERAM OTOT'},
#      {'doc_count': 14.09090909090909, 'key': 'MENGGIGIL'},
#      {'doc_count': 14.09090909090909, 'key': 'MUAL'},
#      {'doc_count': 5.454545454545454, 'key': 'DIARE'},
#      {'doc_count': 5.454545454545454, 'key': 'SAKIT PERUT'}],
#     'missing_data': 96.68524935965044},
#    'jenis_kelamin': {'current_data': 5804,
# ...

# %%
df = pd.json_normalize(data,'list_perkembangan')

# %%
df
# Out:
#            tanggal  KASUS  ...  AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0    1583020800000      3  ...                    0                             3
# 1    1583107200000      0  ...                    0                             3
# 2    1583193600000      1  ...                    1                             3
# 3    1583280000000      1  ...                    1                             4
# 4    1583366400000      0  ...                    1                             4
# ..             ...    ...  ...                  ...                           ...
# 150  1595980800000     97  ...                  203                          2482
# 151  1596067200000    144  ...                  205                          2290
# 152  1596153600000     70  ...                  205                          2343
# 153  1596240000000     61  ...                  205                          2385
# ...

# %%
#df["tanggal"].dtypes

# %%
#a=df["tanggal"]

# %%
#a

# %%
def waktu(data):
  tgl=data["tanggal"]
  tgl_jd = []

  for i in tgl:
    bagi_tgl = i/1000
    tgl_dt = datetime.datetime.fromtimestamp(bagi_tgl)
    tgl_list = [tgl_dt.strftime('%Y-%m-%d')]
    tgl_jd = tgl_jd + tgl_list
  return tgl_jd

# %%
tgl_baru = pd.DataFrame(waktu(df), columns=['waktu'])

# %%
tgl_baru
# Out:
#           waktu
# 0    2020-03-01
# 1    2020-03-02
# 2    2020-03-03
# 3    2020-03-04
# 4    2020-03-05
# ..          ...
# 150  2020-07-29
# 151  2020-07-30
# 152  2020-07-31
# 153  2020-08-01
# 154  2020-08-02
#
# [155 rows x 1 columns]
