# %% [markdown]
# <a href="https://colab.research.google.com/github/setyo-dwi-pratama/covid-19/blob/master/covid_pikobar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests
import urllib3
from urllib3 import request
import certifi
import datetime

# %%
from pandas.io.json import json_normalize

# %%
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
url = 'https://covid19-public.digitalservice.id/api/v1/sebaran/jabar'

# %%
r = http.request('GET', url)

# %%
r.status
# Out:
# 200

# %%
data = json.loads(r.data.decode('utf-8'))

# %%
data
# Out:
# {'data': {'content': [{'gender': 'Perempuan',
#     'id': 'covid-1007201397',
#     'kode_kab': '3203',
#     'kode_kec': '3203170',
#     'kode_kel': '3203170012',
#     'latitude': -6.839,
#     'longitude': 107.247,
#     'nama_kab': 'KAB. CIANJUR',
#     'nama_kec': 'Ciranjang',
#     'nama_kel': 'Nanggalamekar',
#     'stage': 'Proses',
#     'status': 'OTG',
#     'tanggal_konfirmasi': '2020-07-27',
#     'tanggal_update': '2020-07-28',
#     'tanggal_update_nasional': '2020-07-27',
#     'umur': '43.08'},
#    {'gender': 'Perempuan',
#     'id': 'covid-1024204612',
#     'kode_kab': '3277',
#     'kode_kec': '3277030',
#     'kode_kel': '3277030002',
#     'latitude': -6.875,
#     'longitude': 107.558,
#     'nama_kab': 'KOTA CIMAHI',
#     'nama_kec': 'Cimahi Utara',
#     'nama_kel': 'Cibabat',
#     'stage': 'Proses',
#     'status': 'ODP',
#     'tanggal_konfirmasi': '2020-07-27',
#     'tanggal_update': '2020-07-27',
#     'tanggal_update_nasional': '2020-07-27',
# ...

# %%
df = pd.json_normalize(data,max_level=0)

# %%
df
# Out:
#    status_code                                               data
# 0          200  {'metadata': {'last_update': '2020-08-06, 16:1...

# %%
a = df['data'][0]

# %%
a['content']
# Out:
# [{'gender': 'Perempuan',
#   'id': 'covid-1007201397',
#   'kode_kab': '3203',
#   'kode_kec': '3203170',
#   'kode_kel': '3203170012',
#   'latitude': -6.839,
#   'longitude': 107.247,
#   'nama_kab': 'KAB. CIANJUR',
#   'nama_kec': 'Ciranjang',
#   'nama_kel': 'Nanggalamekar',
#   'stage': 'Proses',
#   'status': 'OTG',
#   'tanggal_konfirmasi': '2020-07-27',
#   'tanggal_update': '2020-07-28',
#   'tanggal_update_nasional': '2020-07-27',
#   'umur': '43.08'},
#  {'gender': 'Perempuan',
#   'id': 'covid-1024204612',
#   'kode_kab': '3277',
#   'kode_kec': '3277030',
#   'kode_kel': '3277030002',
#   'latitude': -6.875,
#   'longitude': 107.558,
#   'nama_kab': 'KOTA CIMAHI',
#   'nama_kec': 'Cimahi Utara',
#   'nama_kel': 'Cibabat',
#   'stage': 'Proses',
#   'status': 'ODP',
#   'tanggal_konfirmasi': '2020-07-27',
#   'tanggal_update': '2020-07-27',
#   'tanggal_update_nasional': '2020-07-27',
#   'umur': '60'},
#  {'gender': 'Perempuan',
#   'id': 'covid-1024204614',
# ...

# %%
sebarankab = pd.DataFrame(a['content'])

# %%
sebarankab['nama_kab'].unique()
# Out:
# array(['KAB. CIANJUR', 'KOTA CIMAHI', 'KAB. BANDUNG', 'KOTA BANJAR',
#        'KOTA TASIKMALAYA', 'Kota Bogor', 'KAB. INDRAMAYU',
#        'KAB. PURWAKARTA', 'Kabupaten Cirebon', 'KAB. SUKABUMI',
#        'KAB. CIAMIS', 'KOTA BOGOR', 'KAB. GARUT', 'KAB. TASIKMALAYA',
#        'KAB. MAJALENGKA', 'KAB. KUNINGAN', 'KOTA BANDUNG',
#        'KAB. BANDUNG BARAT', 'KOTA CIREBON', 'KOTA BEKASI', 'KAB. BOGOR',
#        'KAB. BEKASI', 'KOTA DEPOK', 'KOTA SUKABUMI', 'KAB. SUMEDANG',
#        'KAB. CIREBON', 'Kabupaten Pangandaran', 'Kabupaten Bandung',
#        'Kabupaten Ciamis', 'KAB. KARAWANG', 'Kabupaten Subang',
#        'KAB. SUBANG', 'KAB. PANGANDARAN', 'Kota Tasikmalaya',
#        'Kota Banjar', 'Kabupaten Tasikmalaya', 'Kabupaten Sumedang',
#        'Kabupaten Bogor', 'Kabupaten Bekasi', 'Kota Depok',
#        'Kabupaten Bandung Barat', 'Kabupaten Purwakarta', 'Kota Bekasi',
#        'Kota Cimahi', 'Kabupaten Garut', 'Kabupaten Karawang',
# ...
